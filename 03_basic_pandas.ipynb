# %% [markdown]
# ## Introduction Pandas

# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
sns.set(color_codes=True)

# %%
data = pd.read_excel("./database/car.xlsx")

# %%
data.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
data.sample(2)
# Out:
#            Make                  Model  Year             Engine Fuel Type  \
# 507         BMW  5 Series Gran Turismo  2015  premium unleaded (required)
# 6661  Chevrolet            Malibu Maxx  2005             regular unleaded
#
#       Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 507       300.0               6.0         AUTOMATIC    all wheel drive
# 6661      200.0               6.0         AUTOMATIC  front wheel drive
#
#       Number of Doors   Market Category Vehicle Size  Vehicle Style  \
# 507               4.0  Hatchback,Luxury        Large  4dr Hatchback
# 6661              4.0         Hatchback      Midsize  4dr Hatchback
#
#       highway MPG  city mpg  Popularity   MSRP
# 507            26        18        3916  63000
# 6661           28        20        1385  21465

# %%
data.size
# Out:
# 190624

# %%
data.shape
# Out:
# (11914, 16)

# %%
data.tail(2)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11913                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# 11912        16         204  50920
# 11913        17          61  28995

# %%
data['Make'].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
data['Make'].value_counts().sort_index(ascending = True)
# Out:
# Acura             252
# Alfa Romeo          5
# Aston Martin       93
# Audi              328
# BMW               334
# Bentley            74
# Bugatti             3
# Buick             196
# Cadillac          397
# Chevrolet        1123
# Chrysler          187
# Dodge             626
# FIAT               62
# Ferrari            69
# Ford              881
# GMC               515
# Genesis             3
# HUMMER             17
# Honda             449
# Hyundai           303
# Infiniti          330
# Kia               231
# Lamborghini        52
# Land Rover        143
# Lexus             202
# Lincoln           164
# Lotus              29
# Maserati           58
# Maybach            16
# Mazda             423
# McLaren             5
# Mercedes-Benz     353
# Mitsubishi        213
# Nissan            558
# Oldsmobile        150
# Plymouth           82
# Pontiac           186
# Porsche           136
# Rolls-Royce        31
# Saab              111
# Scion              60
# ...

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
data.columns.values
# Out:
# array(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size',
#        'Vehicle Style', 'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype=object)

# %%
len(data.columns)
# Out:
# 16

# %%
data.columns = ["marca", "modelo", "year", "tipo_combustible_motor", "potencia_motor_HP", "cilindrada", "tipo_transmision", "ruedas_motrices", "num_puertas", "categoria_mercado", "vehiculo_size", "estilo_vehiculo", "carretera_MPG", "ciudad_MPG", "popularidad", "precio_vta_sug_fab"]

# %%
data.head(3)
# Out:
#   marca      modelo  year       tipo_combustible_motor  potencia_motor_HP  \
# 0   BMW  1 Series M  2011  premium unleaded (required)              335.0
# 1   BMW    1 Series  2011  premium unleaded (required)              300.0
# 2   BMW    1 Series  2011  premium unleaded (required)              300.0
#
#    cilindrada tipo_transmision   ruedas_motrices  num_puertas  \
# 0         6.0           MANUAL  rear wheel drive          2.0
# 1         6.0           MANUAL  rear wheel drive          2.0
# 2         6.0           MANUAL  rear wheel drive          2.0
#
#                        categoria_mercado vehiculo_size estilo_vehiculo  \
# 0  Factory Tuner,Luxury,High-Performance       Compact           Coupe
# 1                     Luxury,Performance       Compact     Convertible
# 2                Luxury,High-Performance       Compact           Coupe
#
#    carretera_MPG  ciudad_MPG  popularidad  precio_vta_sug_fab
# 0             26          19         3916               46135
# ...

# %%
data.describe(include='all')
# Out:
#             marca          modelo          year tipo_combustible_motor  \
# count       11914           11914  11914.000000                  11911
# unique         48             915           NaN                     10
# top     Chevrolet  Silverado 1500           NaN       regular unleaded
# freq         1123             156           NaN                   7172
# mean          NaN             NaN   2010.384338                    NaN
# std           NaN             NaN      7.579740                    NaN
# min           NaN             NaN   1990.000000                    NaN
# 25%           NaN             NaN   2007.000000                    NaN
# 50%           NaN             NaN   2015.000000                    NaN
# 75%           NaN             NaN   2016.000000                    NaN
# max           NaN             NaN   2017.000000                    NaN
#
#         potencia_motor_HP    cilindrada tipo_transmision    ruedas_motrices  \
# ...

# %%
data["tipo_combustible_motor"].unique()
# Out:
# array(['premium unleaded (required)', 'regular unleaded',
#        'premium unleaded (recommended)', 'flex-fuel (unleaded/E85)',
#        'diesel', 'electric',
#        'flex-fuel (premium unleaded recommended/E85)', 'natural gas',
#        'flex-fuel (premium unleaded required/E85)',
#        'flex-fuel (unleaded/natural gas)', nan], dtype=object)

# %%
sns.boxplot(x = "vehiculo_size", y = "potencia_motor_HP", data = data)
# Out:
# <AxesSubplot:xlabel='vehiculo_size', ylabel='potencia_motor_HP'>

# %%
data.hist(figsize = (20,30))
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'potencia_motor_HP'}>,
#         <AxesSubplot:title={'center':'cilindrada'}>],
#        [<AxesSubplot:title={'center':'num_puertas'}>,
#         <AxesSubplot:title={'center':'carretera_MPG'}>,
#         <AxesSubplot:title={'center':'ciudad_MPG'}>],
#        [<AxesSubplot:title={'center':'popularidad'}>,
#         <AxesSubplot:title={'center':'precio_vta_sug_fab'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(data)

# %%
data.dtypes
# Out:
# marca                      object
# modelo                     object
# year                        int64
# tipo_combustible_motor     object
# potencia_motor_HP         float64
# cilindrada                float64
# tipo_transmision           object
# ruedas_motrices            object
# num_puertas               float64
# categoria_mercado          object
# vehiculo_size              object
# estilo_vehiculo            object
# carretera_MPG               int64
# ciudad_MPG                  int64
# popularidad                 int64
# precio_vta_sug_fab          int64
# dtype: object

# %%
data = data.rename(columns = {
  "potencia_motor_HP":"HP",
  "tipo_transmision":"transmision",
  "tipo_combustible_motor":"combustible",
  "precio_vta_sug_fab":"precio"
})

# %%
data.dtypes
# Out:
# marca                 object
# modelo                object
# year                   int64
# combustible           object
# HP                   float64
# cilindrada           float64
# transmision           object
# ruedas_motrices       object
# num_puertas          float64
# categoria_mercado     object
# vehiculo_size         object
# estilo_vehiculo       object
# carretera_MPG          int64
# ciudad_MPG             int64
# popularidad            int64
# precio                 int64
# dtype: object

# %%
data.head(5)
# Out:
#   marca      modelo  year                  combustible     HP  cilindrada  \
# 0   BMW  1 Series M  2011  premium unleaded (required)  335.0         6.0
# 1   BMW    1 Series  2011  premium unleaded (required)  300.0         6.0
# 2   BMW    1 Series  2011  premium unleaded (required)  300.0         6.0
# 3   BMW    1 Series  2011  premium unleaded (required)  230.0         6.0
# 4   BMW    1 Series  2011  premium unleaded (required)  230.0         6.0
#
#   transmision   ruedas_motrices  num_puertas  \
# 0      MANUAL  rear wheel drive          2.0
# 1      MANUAL  rear wheel drive          2.0
# 2      MANUAL  rear wheel drive          2.0
# 3      MANUAL  rear wheel drive          2.0
# 4      MANUAL  rear wheel drive          2.0
#
#                        categoria_mercado vehiculo_size estilo_vehiculo  \
# 0  Factory Tuner,Luxury,High-Performance       Compact           Coupe
# 1                     Luxury,Performance       Compact     Convertible
# ...

# %%
data.shape
# Out:
# (11914, 16)

# %%
sns.boxplot(x = data['HP'])
# Out:
# <AxesSubplot:xlabel='HP'>

# %%
sns.boxplot(x = data["precio"])
# Out:
# <AxesSubplot:xlabel='precio'>

# %% [markdown]
# histograma de autos por marca

# %%
data.marca.value_counts().nlargest(30).plot(kind= "bar", figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# relación entre variables

# %%
plt.figure(figsize=(20,10))
c = data.corr()
c
sns.heatmap(c, cmap = "BrBG", annot = True)
# Out:
# <AxesSubplot:>

# %%
c
# Out:
#                    year        HP  cilindrada  num_puertas  carretera_MPG  \
# year           1.000000  0.351794   -0.041479     0.263787       0.258240
# HP             0.351794  1.000000    0.779988    -0.102713      -0.406563
# cilindrada    -0.041479  0.779988    1.000000    -0.140088      -0.621606
# num_puertas    0.263787 -0.102713   -0.140088     1.000000       0.118570
# carretera_MPG  0.258240 -0.406563   -0.621606     0.118570       1.000000
# ciudad_MPG     0.198171 -0.439371   -0.600776     0.120881       0.886829
# popularidad    0.073049  0.037501    0.041145    -0.048272      -0.020991
# precio         0.227590  0.662008    0.531312    -0.126635      -0.160043
#
#                ciudad_MPG  popularidad    precio
# year             0.198171     0.073049  0.227590
# HP              -0.439371     0.037501  0.662008
# cilindrada      -0.600776     0.041145  0.531312
# num_puertas      0.120881    -0.048272 -0.126635
# carretera_MPG    0.886829    -0.020991 -0.160043
# ...
